# %% [markdown]
# # WoMAD Model: Results and Interpretation
# This section of the code will contain all necessary code required for the visualization and interpretation of the model outputs. The outputs in `./models/model_outputs/` will be put to the test in this notebook.
#
# Steps for visualization and interpretation:
# - \[List of steps will be inserted.]
#
# This notebook evaluates the model outputs. Evaluation of the model itself will be carried out in `.ipynb` file `04` titled `04_model_evaluation.ipynb`.
#
# The results of this notebook will be locally saved in the `./models/model_outputs/` and `./figures` folders of the repository. If you are using these codes directly, please follow the same naming structure.

# %% [markdown]
# ## Requirements and Setup
# Let us first set up our environment to start the result interpretation.

# %%
# Requirements and Setup codes (and, if needed, helper functions) will be inserted here.
