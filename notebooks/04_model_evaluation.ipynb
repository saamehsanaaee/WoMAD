# %% [markdown]
# # WoMAD Model: Model Evaluation
# This section of the code will contain all necessary code required for the evaluation of our model. The pretrained models in `./models/pretrained_models/` will be put to the test here.
#
# Steps of our evaluation:
# - \[List of steps will be inserted.]
#
# This notebook evaluates the model itself. Evaluation, analysis, and interpretation of its results will be carried out in `.ipynb` file `05` titled `05_results_and_interpretation.ipynb`.
#
# Any quantitative output from this evaluation will be locally saved in the `./models/model_evaluation/` folder of the repository. If you are using these codes directly, please follow the same naming structure.

# %% [markdown]
# ## Requirements and Setup
# Let us first set up our environment to start the model evaluation.

# %%
# Requirements and Setup codes (and, if needed, helper functions) will be inserted here.
