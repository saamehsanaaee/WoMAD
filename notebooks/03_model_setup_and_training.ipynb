# %% [markdown]
# # WoMAD Model: Model Setup and Training
# This section of the code will contain all necessary code required for the setup of our model, followed by the its training. The "model-ready" data will be used here and the output of the model will be saved as well.
#
# Our model structure:
# - \[List of modules will be inserted.]
#
# In separate notebooks, the model will be evaluated and its results will be analyzed and interpreted. This notebook will simply hold the setup, training, and allow us to generate the outputs.
#
# The output files, the pretrained models and the model outputs, will be locally saved in the `./models/pretrained_models/` and `./models/model_outputs` folders of the repository. If you are using these codes directly, please follow the same naming structure.

# %% [markdown]
# \[Model outline will be inserted.]

# %% [markdown]
# ## Requirements and Setup
# Let us first set up our environment to start the model setup and training.

# %%
# Requirements and Setup codes (and, if needed, helper functions) will be inserted here.
