# %% [markdown]
# # WoMAD Model: Global Utilities and Helper Functions
# This section of the code will contain all necessary utilities and helper functions that is used throughout the pipeline. This mostly includes modified save functions or other similar functions.

# %% [markdown]
# ## Requirements and Setup
# Let us first set up our environment with required packages, installs, and parameters.

# %%
# Requirements and Setup codes will be inserted here.

# %% [markdown]
# ## Helper Functions

# %%
# Helper functions will be inserted here.
