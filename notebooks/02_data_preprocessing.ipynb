# %% [markdown]
# # WoMAD Model: Project-specific Data Preprocessing
# This section of the code will contain all necessary code required for the project-specific preprocessing required on top of the processing we did during the EDA. We need this step to ensure that the data is in a "model-ready" state. Preprocessing will require changes to format, dimensions, and organization of the data.
#
# Our model structure (outlined bellow) and requires changes to these files:
# - \[List of files will be inserted.]
#
# These files will be locally saved in the `./data/model_ready/` folder of the repository. If you are using these codes directly, please follow the same naming structure.

# %% [markdown]
# \[Model outline will be inserted.]

# %% [markdown]
# ## Requirements and Setup

# %% [markdown]
# ## Input-Layer Specifics
# Here are the changes required for the data to be ready for the input layer of the WoMAD model.

# %% [markdown]
# ## Module Specifics
# Here are the changes required for each module of the WoMAD model.

# %%
### Module One
### Module Two
### Module Three
### Module Four
### Module Five

# %% [markdown]
# ## Project-specific Preprocessing Results
# As mentioned, the preprocessing results will be stored in the `./data/model_ready` folder of the repository.
